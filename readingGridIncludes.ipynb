# %%
import os
import numpy as np

# %%
path = r'A:\Scratch\Amin\GRDECL for Turaj'
file_name = 'FSC_RESERVES_2020_PROP_FIPNUM.GRDECL'
grid = []
grid_init = []

with open(os.path.join(path, file_name), 'r') as f:
    base = f.readlines()
    
line_number = 0
flag = 0

for item in base:
    item = item.strip()
    
    if flag == 0 and item[:12] == '--Matrix Box':
        flag = 0.5
        continue
        
    elif flag == 0.5:
        dimen = item.split(" ")
        flag = 1

    elif item[:6] == 'ENDBOX' and flag == 2:
        last_line = line_number
        flag = 3
    
    elif item.find('*') > 0   and flag == 1:
        first_line = line_number + 1
        flag = 2
    
    line_number += 1
    
grid_inc = base[first_line:last_line]

X = int(dimen[1])
Y = int(dimen[3])
Z = int(dimen[5])

total_cell_count = X * Y * Z  # this returns the total number of the cells in the model

# %%
for line in grid_inc:
    line = line.strip()
    grid_item = line.split(" ")
    
    for item in grid_item:
        grid_init.append(item) # This is a list of all the values for the grid

# %%
for item in grid_init:
    ast_loc = item.find('*')
    
    if ast_loc > 0:
        counter = int(item[:ast_loc])
        grid.append(counter)
    
    elif item != "/":
        grid.append(int(item))
        
print(grid)
# Out:
# [12686, 3, 464, 3, 462, 5, 460, 7, 457, 10, 19, 3, 435, 11, 18, 3, 433, 13, 16, 5, 431, 15, 13, 8, 429, 11, 6, 11, 10, 426, 19, 10, 12, 424, 21, 8, 13, 423, 23, 5, 16, 421, 25, 3, 18, 419, 27, 1, 20, 416, 51, 11, 403, 53, 412, 55, 410, 56, 409, 58, 407, 60, 404, 63, 402, 65, 400, 67, 398, 69, 396, 70, 394, 73, 392, 2, 73, 390, 77, 388, 79, 385, 82, 383, 83, 382, 85, 380, 87, 378, 89, 375, 92, 373, 94, 371, 95, 370, 97, 2, 366, 99, 366, 101, 363, 104, 361, 105, 360, 107, 358, 109, 356, 111, 353, 114, 351, 116, 349, 117, 348, 2, 117, 346, 121, 343, 124, 341, 126, 339, 128, 337, 129, 336, 131, 333, 134, 331, 136, 329, 138, 327, 140, 2, 322, 142, 323, 144, 321, 146, 319, 148, 317, 150, 315, 152, 315, 151, 316, 151, 316, 151, 316, 151, 315, 2, 150, 315, 151, 316, 151, 316, 151, 316, 151, 315, 152, 315, 152, 315, 151, 316, 151, 316, 151, 316, 151, 2, 313, 152, 315, 152, 315, 151, 316, 151, 316, 151, 315, 152, 315, 152, 315, 152, 315, 151, 316, 151, 315, 2, 150, 315, 152, 315, 152, 315, 152, 315, 152, 315, 151, 315, 152, 315, 152, 315, 152, 315, 152, 315, 152, 2, 313, 151, 315, 152, 315, 152, 315, 152, 315, 152, 315, 152, 315, 151, 315, 152, 315, 152, 315, 152, 315, 2, 150, 315, 152, 315, 151, 315, 152, 315, 152, 315, 152, 315, 152, 315, 152, 314, 152, 315, 152, 315, 152, 2, 313, 152, 315, 152, 315, 152, 314, 152, 315, 152, 315, 152, 315, 152, 315, 152, 315, 152, 314, 151, 4, 315, 3, 148, 3, 315, 147, 5, 315, 145, 7, 315, 143, 8, 2, 315, 141, 10, 2, 314, 140, 12, 315, 137, 15, 315, 135, 2, 15, 315, 133, 19, 315, 131, 21, 315, 129, 23, 314, 128, 24, 315, 126, 26, 315, 123, 29, 315, 121, 31, 11, 304, 119, 33, 315, 117, 35, 314, 116, 2, 36, 314, 114, 2, 3, 34, 315, 111, 2, 6, 34, 315, 109, 2, 8, 34